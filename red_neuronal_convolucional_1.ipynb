# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from matplotlib import *
import matplotlib.pyplot as plt

# %%
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
#formato de las imágenes
img_width, img_height = 48,48

# %%
train_data_dir ='C:/Users/mmaccari/images/images/train'
validation_data_dir ='C:/Users/mmaccari/images/images/validation'
nb_train_samples = 28821
nb_validation_samples = 7066
epochs = 100
batch_size = 32 #cant de imagenes que pasan por la red neuronal antes de actualizar los pesos
kernel_size = 3
pool_size = 2
num_classes = 7

# %%
#3 si las imágenes son a color, 1 si las imágenes son blanco y negro
if K.image_data_format() == 'channels_first':
 input_shape = (3, img_width, img_height)
else:
 input_shape = (img_width, img_height, 3)

# %% [markdown]
# Tamaño de filtro: cuántos mapas de caracteristicas quiero crear. filters 32 detectors en la primera capa(32,3,3)
# Kernel size: tamaño de cada uno de los filtros(3,3) tamaño de las ventanas
# padding: gestionar si la ventana esta centrada en un pixel o desplazada hacia la izq o derecha. Same=centrado
# input shape: filas, columnas, color o blanco y negro
# Funcion de activacion: relu para eliminar pixeles negativos

# %%
model = Sequential()

#Primera capa oculta de 32 filtros, kernel de 3x3 y poolsize de 2x2
#capa de convolucion
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(48, 48, 1)))
model.add(Activation('relu'))

#capa de max pooling(me quedo con el valor máximo, los mapas de caracteristicas se reducen)
model.add(MaxPooling2D(pool_size=(pool_size, pool_size),))
model.add(Dropout(0.2))

#Segunda capa oculta de 64 filtros, kernel de 3x3 
model.add(Conv2D(64, (kernel_size, kernel_size),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))#poolsize de 2x2 (tamaño de la ventana que se aplica, matriz 2*2)
model.add(Dropout(0.2))

#Tercera capa oculta de 128 filtros, kernel de 3x3 y poolsize de 2x2
model.add(Conv2D(128, (3, 3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))
model.add(Dropout(0.2))

#Flattening, aplanar los datos a un vector vertical, los mapas de caracteristicas se aplanan,será la entrada a la red neuronal.
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.5))

#red neuronal totalmente conectada, full connection
model.add(Dense(128)) #son los nodos 
model.add(Activation('relu'))
model.add(Dropout(0.5))

#red neuronal totalmente conectada, full connection
model.add(Dense(64)) #son los nodos 
model.add(Activation('relu'))
model.add(Dropout(0.5))

#capa de salida, funcion de activacion sigmoid. Probabilidad de clases=7
model.add(Dense(7))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_67 (Conv2D)           (None, 48, 48, 32)        320
# _________________________________________________________________
# activation_66 (Activation)   (None, 48, 48, 32)        0
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_67 (Activation)   (None, 24, 24, 64)        0
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# activation_68 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_76 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 1152)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               147584
# _________________________________________________________________
# activation_69 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 64)                8256
# _________________________________________________________________
# activation_70 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 7)                 455
# _________________________________________________________________
# activation_71 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 248,967
# Trainable params: 248,967
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
 optimizer=Adam(lr=0.001),
 metrics=['accuracy'])

# %%
#Preproceso, rotaciones, cambios de escala (0 a 1), zoom. Incrementar la cantidad de imágenes.
train_datagen = ImageDataGenerator(
 rescale=1. / 255,
 shear_range=0.2,
 zoom_range=0.2,#Rango para zoom aleatorio
 horizontal_flip=True)#Voltea aleatoriamente las entradas horizontalmente.

# %%
#Valores de 0 a 1
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#training dataset
train_generator = train_datagen.flow_from_directory(
train_data_dir,
target_size=(img_width, img_height),
color_mode="grayscale",
batch_size=batch_size,
class_mode='categorical') #7 clases

#validation dataset
validation_generator = test_datagen.flow_from_directory(
validation_data_dir,
target_size=(img_width, img_height),
color_mode="grayscale",
batch_size=batch_size,
class_mode='categorical', 
shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral).

# %%
# Para guardar el modelo que ha dado mejor rendimiento. Supervisa la pérdida total del modelo ("val_loss")
checkpoint = ModelCheckpoint('analisis_emociones_faciales.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=3)

# Dejar de entrenar cuando una métrica monitoreada haya dejado de mejorar. Patience: luego de 20 epocas sin mejora deja de entrenar
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=20,
                          verbose=3,
                          restore_best_weights=True
                          )

#Reducir la tasa de aprendizaje cuando una métrica haya dejado de mejorar.
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=3,
                              min_delta=0.0001)

callbacks = [checkpoint] #[earlystop,checkpoint,reduce_lr]

# %% [markdown]
# Accuracy: precision. Porcentaje de aciertos
# Loss: pérdida. Mide el error entre la salida predicha y la salida deseada.

# %% [markdown]
# Loss y accuracy son los resultados sobre el conj de train.
# Val_loss y val_accuracy(deberia superar 0,80) son los resultados sobre el conj de testing

# %%
#Entrenar el modelo
history=model.fit_generator(
     train_generator,
     steps_per_epoch=nb_train_samples // batch_size, #conjunto de train. quitar batch_size???
     epochs=epochs,
    callbacks=callbacks,
     validation_data=validation_generator,
     validation_steps=nb_validation_samples // batch_size)#conjunto de validacion
# Out:
# Epoch 1/100
# 900/900 [==============================] - 177s 196ms/step - loss: 1.8293 - accuracy: 0.2433 - val_loss: 1.9644 - val_accuracy: 0.2594
#
# Epoch 00001: val_loss improved from inf to 1.96437, saving model to analisis_emociones_faciales.h5.h5
# Epoch 2/100
# 900/900 [==============================] - 174s 193ms/step - loss: 1.7996 - accuracy: 0.2510 - val_loss: 1.8123 - val_accuracy: 0.2775
#
# Epoch 00002: val_loss improved from 1.96437 to 1.81229, saving model to analisis_emociones_faciales.h5.h5
# Epoch 3/100
# 900/900 [==============================] - 187s 208ms/step - loss: 1.7809 - accuracy: 0.2602 - val_loss: 1.7604 - val_accuracy: 0.2967
#
# Epoch 00003: val_loss improved from 1.81229 to 1.76040, saving model to analisis_emociones_faciales.h5.h5
# Epoch 4/100
# 900/900 [==============================] - 160s 178ms/step - loss: 1.7416 - accuracy: 0.2818 - val_loss: 1.7533 - val_accuracy: 0.3129
#
# Epoch 00004: val_loss improved from 1.76040 to 1.75327, saving model to analisis_emociones_faciales.h5.h5
# Epoch 5/100
# 900/900 [==============================] - 152s 169ms/step - loss: 1.7176 - accuracy: 0.2969 - val_loss: 1.5278 - val_accuracy: 0.3267
#
# Epoch 00005: val_loss improved from 1.75327 to 1.52782, saving model to analisis_emociones_faciales.h5.h5
# Epoch 6/100
# 900/900 [==============================] - 165s 183ms/step - loss: 1.7001 - accuracy: 0.3052 - val_loss: 1.2194 - val_accuracy: 0.3260
#
# Epoch 00006: val_loss improved from 1.52782 to 1.21941, saving model to analisis_emociones_faciales.h5.h5
# Epoch 7/100
# 900/900 [==============================] - 166s 184ms/step - loss: 1.6881 - accuracy: 0.3143 - val_loss: 1.5032 - val_accuracy: 0.3477
#
# Epoch 00007: val_loss did not improve from 1.21941
# Epoch 8/100
# 900/900 [==============================] - 173s 192ms/step - loss: 1.6673 - accuracy: 0.3299 - val_loss: 1.4031 - val_accuracy: 0.3908
#
# Epoch 00008: val_loss did not improve from 1.21941
# Epoch 9/100
# 900/900 [==============================] - 160s 178ms/step - loss: 1.6512 - accuracy: 0.3443 - val_loss: 1.5716 - val_accuracy: 0.4096
#
# Epoch 00009: val_loss did not improve from 1.21941
# Epoch 10/100
# 900/900 [==============================] - 160s 178ms/step - loss: 1.6264 - accuracy: 0.3564 - val_loss: 1.3359 - val_accuracy: 0.4417
#
# Epoch 00010: val_loss did not improve from 1.21941
# Epoch 11/100
# 900/900 [==============================] - 160s 178ms/step - loss: 1.6030 - accuracy: 0.3684 - val_loss: 1.3772 - val_accuracy: 0.4504
#
# Epoch 00011: val_loss did not improve from 1.21941
# Epoch 12/100
# 900/900 [==============================] - 159s 177ms/step - loss: 1.5860 - accuracy: 0.3804 - val_loss: 1.1057 - val_accuracy: 0.4595
#
# Epoch 00012: val_loss improved from 1.21941 to 1.10575, saving model to analisis_emociones_faciales.h5.h5
# Epoch 13/100
# 900/900 [==============================] - 153s 170ms/step - loss: 1.5719 - accuracy: 0.3854 - val_loss: 1.1144 - val_accuracy: 0.4495
#
# Epoch 00013: val_loss did not improve from 1.10575
# Epoch 14/100
# 900/900 [==============================] - 153s 170ms/step - loss: 1.5563 - accuracy: 0.3942 - val_loss: 1.5809 - val_accuracy: 0.4357
#
# Epoch 00014: val_loss did not improve from 1.10575
# Epoch 15/100
# 900/900 [==============================] - 156s 173ms/step - loss: 1.5481 - accuracy: 0.3992 - val_loss: 1.7885 - val_accuracy: 0.4699
#
# Epoch 00015: val_loss did not improve from 1.10575
# Epoch 16/100
# 900/900 [==============================] - 149s 165ms/step - loss: 1.5375 - accuracy: 0.4048 - val_loss: 0.8870 - val_accuracy: 0.4726
#
# Epoch 00016: val_loss improved from 1.10575 to 0.88698, saving model to analisis_emociones_faciales.h5.h5
# Epoch 17/100
# 900/900 [==============================] - 147s 163ms/step - loss: 1.5256 - accuracy: 0.4077 - val_loss: 1.1951 - val_accuracy: 0.4829
#
# Epoch 00017: val_loss did not improve from 0.88698
# Epoch 18/100
# 900/900 [==============================] - 155s 172ms/step - loss: 1.5187 - accuracy: 0.4124 - val_loss: 1.0769 - val_accuracy: 0.4888
#
# Epoch 00018: val_loss did not improve from 0.88698
# Epoch 19/100
# 900/900 [==============================] - 151s 168ms/step - loss: 1.5112 - accuracy: 0.4183 - val_loss: 1.2521 - val_accuracy: 0.4801
#
# Epoch 00019: val_loss did not improve from 0.88698
# Epoch 20/100
# 900/900 [==============================] - 153s 170ms/step - loss: 1.5104 - accuracy: 0.4191 - val_loss: 1.2367 - val_accuracy: 0.4866
#
# Epoch 00020: val_loss did not improve from 0.88698
# Epoch 21/100
# 900/900 [==============================] - 150s 166ms/step - loss: 1.4978 - accuracy: 0.4208 - val_loss: 1.0374 - val_accuracy: 0.4937
#
# Epoch 00021: val_loss did not improve from 0.88698
# Epoch 22/100
# 900/900 [==============================] - 159s 177ms/step - loss: 1.4928 - accuracy: 0.4224 - val_loss: 0.9029 - val_accuracy: 0.4935
#
# Epoch 00022: val_loss did not improve from 0.88698
# Epoch 23/100
# 900/900 [==============================] - 179s 199ms/step - loss: 1.4841 - accuracy: 0.4290 - val_loss: 1.1873 - val_accuracy: 0.4996
#
# Epoch 00023: val_loss did not improve from 0.88698
# Epoch 24/100
# 900/900 [==============================] - 168s 187ms/step - loss: 1.4730 - accuracy: 0.4285 - val_loss: 1.0370 - val_accuracy: 0.4983
#
# Epoch 00024: val_loss did not improve from 0.88698
# Epoch 25/100
# 900/900 [==============================] - 158s 176ms/step - loss: 1.4726 - accuracy: 0.4321 - val_loss: 1.5518 - val_accuracy: 0.5033
#
# Epoch 00025: val_loss did not improve from 0.88698
# Epoch 26/100
# 900/900 [==============================] - 152s 169ms/step - loss: 1.4684 - accuracy: 0.4361 - val_loss: 1.4192 - val_accuracy: 0.5141
#
# Epoch 00026: val_loss did not improve from 0.88698
# Epoch 27/100
# 900/900 [==============================] - 152s 169ms/step - loss: 1.4629 - accuracy: 0.4356 - val_loss: 1.5431 - val_accuracy: 0.4977
#
# Epoch 00027: val_loss did not improve from 0.88698
# Epoch 28/100
# 900/900 [==============================] - 154s 171ms/step - loss: 1.4600 - accuracy: 0.4364 - val_loss: 1.3933 - val_accuracy: 0.5165
#
# Epoch 00028: val_loss did not improve from 0.88698
# Epoch 29/100
# 900/900 [==============================] - 150s 166ms/step - loss: 1.4539 - accuracy: 0.4401 - val_loss: 1.2986 - val_accuracy: 0.5166
#
# Epoch 00029: val_loss did not improve from 0.88698
# Epoch 30/100
# 900/900 [==============================] - 156s 173ms/step - loss: 1.4505 - accuracy: 0.4387 - val_loss: 1.5903 - val_accuracy: 0.5112
#
# Epoch 00030: val_loss did not improve from 0.88698
# Epoch 31/100
# 900/900 [==============================] - 154s 171ms/step - loss: 1.4491 - accuracy: 0.4442 - val_loss: 1.4746 - val_accuracy: 0.5210
#
# Epoch 00031: val_loss did not improve from 0.88698
# Epoch 32/100
# 900/900 [==============================] - 152s 169ms/step - loss: 1.4400 - accuracy: 0.4437 - val_loss: 1.5661 - val_accuracy: 0.5193
#
# Epoch 00032: val_loss did not improve from 0.88698
# Epoch 33/100
# 900/900 [==============================] - 147s 163ms/step - loss: 1.4390 - accuracy: 0.4436 - val_loss: 1.5015 - val_accuracy: 0.4972
#
# Epoch 00033: val_loss did not improve from 0.88698
# Epoch 34/100
# 900/900 [==============================] - 147s 163ms/step - loss: 1.4334 - accuracy: 0.4499 - val_loss: 1.4182 - val_accuracy: 0.5226
#
# Epoch 00034: val_loss did not improve from 0.88698
# Epoch 35/100
# 900/900 [==============================] - 150s 166ms/step - loss: 1.4359 - accuracy: 0.4513 - val_loss: 1.4492 - val_accuracy: 0.5206
#
# Epoch 00035: val_loss did not improve from 0.88698
# Epoch 36/100
# 900/900 [==============================] - 155s 173ms/step - loss: 1.4311 - accuracy: 0.4551 - val_loss: 1.4683 - val_accuracy: 0.5313
#
# Epoch 00036: val_loss did not improve from 0.88698
# Epoch 37/100
# 900/900 [==============================] - 156s 173ms/step - loss: 1.4256 - accuracy: 0.4534 - val_loss: 1.4330 - val_accuracy: 0.5252
#
# Epoch 00037: val_loss did not improve from 0.88698
# Epoch 38/100
# 900/900 [==============================] - 188s 209ms/step - loss: 1.4271 - accuracy: 0.4524 - val_loss: 1.4697 - val_accuracy: 0.5266
#
# Epoch 00038: val_loss did not improve from 0.88698
# Epoch 39/100
# 900/900 [==============================] - 152s 169ms/step - loss: 1.4279 - accuracy: 0.4536 - val_loss: 1.4985 - val_accuracy: 0.5252
#
# Epoch 00039: val_loss did not improve from 0.88698
# Epoch 40/100
# 900/900 [==============================] - 143s 159ms/step - loss: 1.4236 - accuracy: 0.4570 - val_loss: 1.4082 - val_accuracy: 0.5215
#
# Epoch 00040: val_loss did not improve from 0.88698
# Epoch 41/100
# 900/900 [==============================] - 154s 171ms/step - loss: 1.4204 - accuracy: 0.4588 - val_loss: 1.5032 - val_accuracy: 0.5226
#
# Epoch 00041: val_loss did not improve from 0.88698
# Epoch 42/100
# 900/900 [==============================] - 146s 163ms/step - loss: 1.4181 - accuracy: 0.4566 - val_loss: 1.4449 - val_accuracy: 0.5071
#
# Epoch 00042: val_loss did not improve from 0.88698
# Epoch 43/100
# 900/900 [==============================] - 157s 174ms/step - loss: 1.4059 - accuracy: 0.4604 - val_loss: 1.4234 - val_accuracy: 0.5343
#
# Epoch 00043: val_loss did not improve from 0.88698
# Epoch 44/100
# 900/900 [==============================] - 145s 161ms/step - loss: 1.4103 - accuracy: 0.4626 - val_loss: 1.4612 - val_accuracy: 0.5227
#
# Epoch 00044: val_loss did not improve from 0.88698
# Epoch 45/100
# 900/900 [==============================] - 148s 165ms/step - loss: 1.4109 - accuracy: 0.4610 - val_loss: 1.3156 - val_accuracy: 0.5412
#
# Epoch 00045: val_loss did not improve from 0.88698
# Epoch 46/100
# 900/900 [==============================] - 239s 266ms/step - loss: 1.4139 - accuracy: 0.4616 - val_loss: 1.5511 - val_accuracy: 0.5344
#
# Epoch 00046: val_loss did not improve from 0.88698
# Epoch 47/100
# 900/900 [==============================] - 233s 259ms/step - loss: 1.4007 - accuracy: 0.4681 - val_loss: 1.4447 - val_accuracy: 0.5291
#
# Epoch 00047: val_loss did not improve from 0.88698
# Epoch 48/100
# 900/900 [==============================] - 220s 245ms/step - loss: 1.4076 - accuracy: 0.4629 - val_loss: 1.7004 - val_accuracy: 0.5303
#
# Epoch 00048: val_loss did not improve from 0.88698
# Epoch 49/100
# 900/900 [==============================] - 230s 256ms/step - loss: 1.4115 - accuracy: 0.4636 - val_loss: 1.4922 - val_accuracy: 0.5402
#
# Epoch 00049: val_loss did not improve from 0.88698
# Epoch 50/100
# 900/900 [==============================] - 230s 255ms/step - loss: 1.3969 - accuracy: 0.4693 - val_loss: 1.4918 - val_accuracy: 0.5375
#
# Epoch 00050: val_loss did not improve from 0.88698
# Epoch 51/100
# 900/900 [==============================] - 217s 241ms/step - loss: 1.4023 - accuracy: 0.4668 - val_loss: 1.3067 - val_accuracy: 0.5415
#
# Epoch 00051: val_loss did not improve from 0.88698
# Epoch 52/100
# 900/900 [==============================] - 219s 243ms/step - loss: 1.3934 - accuracy: 0.4683 - val_loss: 1.3878 - val_accuracy: 0.5381
#
# Epoch 00052: val_loss did not improve from 0.88698
# Epoch 53/100
# 900/900 [==============================] - 220s 244ms/step - loss: 1.3996 - accuracy: 0.4671 - val_loss: 1.2689 - val_accuracy: 0.5492
#
# Epoch 00053: val_loss did not improve from 0.88698
# Epoch 54/100
# 900/900 [==============================] - 217s 241ms/step - loss: 1.4031 - accuracy: 0.4687 - val_loss: 1.4861 - val_accuracy: 0.5354
#
# Epoch 00054: val_loss did not improve from 0.88698
# Epoch 55/100
# 900/900 [==============================] - 229s 255ms/step - loss: 1.3920 - accuracy: 0.4718 - val_loss: 1.3274 - val_accuracy: 0.5490
#
# Epoch 00055: val_loss did not improve from 0.88698
# Epoch 56/100
# 900/900 [==============================] - 224s 249ms/step - loss: 1.3940 - accuracy: 0.4696 - val_loss: 1.4647 - val_accuracy: 0.5500
#
# Epoch 00056: val_loss did not improve from 0.88698
# Epoch 57/100
# 900/900 [==============================] - 217s 242ms/step - loss: 1.3876 - accuracy: 0.4704 - val_loss: 1.4511 - val_accuracy: 0.5303
#
# Epoch 00057: val_loss did not improve from 0.88698
# Epoch 58/100
# 900/900 [==============================] - 213s 236ms/step - loss: 1.3934 - accuracy: 0.4654 - val_loss: 1.4513 - val_accuracy: 0.5432
#
# Epoch 00058: val_loss did not improve from 0.88698
# Epoch 59/100
# 900/900 [==============================] - 217s 242ms/step - loss: 1.3827 - accuracy: 0.4701 - val_loss: 1.3639 - val_accuracy: 0.5498
#
# Epoch 00059: val_loss did not improve from 0.88698
# Epoch 60/100
# 900/900 [==============================] - 229s 254ms/step - loss: 1.3908 - accuracy: 0.4739 - val_loss: 1.2894 - val_accuracy: 0.5458
#
# Epoch 00060: val_loss did not improve from 0.88698
# Epoch 61/100
# 900/900 [==============================] - 225s 250ms/step - loss: 1.3893 - accuracy: 0.4708 - val_loss: 1.1936 - val_accuracy: 0.5458
#
# Epoch 00061: val_loss did not improve from 0.88698
# Epoch 62/100
# 900/900 [==============================] - 221s 246ms/step - loss: 1.3888 - accuracy: 0.4705 - val_loss: 1.1559 - val_accuracy: 0.5358
#
# Epoch 00062: val_loss did not improve from 0.88698
# Epoch 63/100
# 900/900 [==============================] - 219s 243ms/step - loss: 1.3797 - accuracy: 0.4748 - val_loss: 1.0242 - val_accuracy: 0.5542
#
# Epoch 00063: val_loss did not improve from 0.88698
# Epoch 64/100
# 900/900 [==============================] - 220s 245ms/step - loss: 1.3879 - accuracy: 0.4730 - val_loss: 1.3061 - val_accuracy: 0.5405
#
# Epoch 00064: val_loss did not improve from 0.88698
# Epoch 65/100
# 900/900 [==============================] - 224s 249ms/step - loss: 1.3852 - accuracy: 0.4734 - val_loss: 1.2700 - val_accuracy: 0.5469
#
# Epoch 00065: val_loss did not improve from 0.88698
# Epoch 66/100
# 900/900 [==============================] - 216s 241ms/step - loss: 1.3766 - accuracy: 0.4771 - val_loss: 1.2049 - val_accuracy: 0.5439
#
# Epoch 00066: val_loss did not improve from 0.88698
# Epoch 67/100
# 900/900 [==============================] - 216s 240ms/step - loss: 1.3736 - accuracy: 0.4785 - val_loss: 1.2620 - val_accuracy: 0.5503
#
# Epoch 00067: val_loss did not improve from 0.88698
# Epoch 68/100
# 900/900 [==============================] - 219s 244ms/step - loss: 1.3835 - accuracy: 0.4730 - val_loss: 1.1538 - val_accuracy: 0.5405
#
# Epoch 00068: val_loss did not improve from 0.88698
# Epoch 69/100
# 900/900 [==============================] - 219s 243ms/step - loss: 1.3773 - accuracy: 0.4750 - val_loss: 1.0134 - val_accuracy: 0.5500
#
# Epoch 00069: val_loss did not improve from 0.88698
# Epoch 70/100
# 900/900 [==============================] - 216s 241ms/step - loss: 1.3829 - accuracy: 0.4766 - val_loss: 1.0882 - val_accuracy: 0.5462
#
# Epoch 00070: val_loss did not improve from 0.88698
# Epoch 71/100
# 900/900 [==============================] - 222s 247ms/step - loss: 1.3736 - accuracy: 0.4776 - val_loss: 1.2601 - val_accuracy: 0.5407
#
# Epoch 00071: val_loss did not improve from 0.88698
# Epoch 72/100
# 900/900 [==============================] - 220s 245ms/step - loss: 1.3698 - accuracy: 0.4784 - val_loss: 1.1248 - val_accuracy: 0.5333
#
# Epoch 00072: val_loss did not improve from 0.88698
# Epoch 73/100
# 900/900 [==============================] - 212s 236ms/step - loss: 1.3832 - accuracy: 0.4779 - val_loss: 1.0857 - val_accuracy: 0.5417
#
# Epoch 00073: val_loss did not improve from 0.88698
# Epoch 74/100
# 900/900 [==============================] - 217s 241ms/step - loss: 1.3726 - accuracy: 0.4820 - val_loss: 1.1298 - val_accuracy: 0.5459
#
# Epoch 00074: val_loss did not improve from 0.88698
# Epoch 75/100
# 900/900 [==============================] - 217s 242ms/step - loss: 1.3774 - accuracy: 0.4783 - val_loss: 1.2022 - val_accuracy: 0.5466
#
# Epoch 00075: val_loss did not improve from 0.88698
# Epoch 76/100
# 900/900 [==============================] - 240s 267ms/step - loss: 1.3692 - accuracy: 0.4808 - val_loss: 1.4527 - val_accuracy: 0.5562
#
# Epoch 00076: val_loss did not improve from 0.88698
# Epoch 77/100
# 900/900 [==============================] - 229s 254ms/step - loss: 1.3808 - accuracy: 0.4754 - val_loss: 1.5452 - val_accuracy: 0.5599
#
# Epoch 00077: val_loss did not improve from 0.88698
# Epoch 78/100
# 900/900 [==============================] - 234s 260ms/step - loss: 1.3678 - accuracy: 0.4804 - val_loss: 1.0972 - val_accuracy: 0.5520
#
# Epoch 00078: val_loss did not improve from 0.88698
# Epoch 79/100
# 900/900 [==============================] - 244s 271ms/step - loss: 1.3653 - accuracy: 0.4822 - val_loss: 1.0292 - val_accuracy: 0.5537
#
# Epoch 00079: val_loss did not improve from 0.88698
# Epoch 80/100
# 900/900 [==============================] - 242s 269ms/step - loss: 1.3722 - accuracy: 0.4793 - val_loss: 1.2046 - val_accuracy: 0.5512
#
# Epoch 00080: val_loss did not improve from 0.88698
# Epoch 81/100
# 900/900 [==============================] - 389s 432ms/step - loss: 1.3693 - accuracy: 0.4804 - val_loss: 1.2732 - val_accuracy: 0.5540
#
# Epoch 00081: val_loss did not improve from 0.88698
# Epoch 82/100
# 900/900 [==============================] - 222s 247ms/step - loss: 1.3667 - accuracy: 0.4834 - val_loss: 1.1086 - val_accuracy: 0.5543
#
# Epoch 00082: val_loss did not improve from 0.88698
# Epoch 83/100
# 900/900 [==============================] - 223s 248ms/step - loss: 1.3699 - accuracy: 0.4805 - val_loss: 0.7321 - val_accuracy: 0.5353
#
# Epoch 00083: val_loss improved from 0.88698 to 0.73210, saving model to analisis_emociones_faciales.h5.h5
# Epoch 84/100
# 900/900 [==============================] - 216s 240ms/step - loss: 1.3699 - accuracy: 0.4809 - val_loss: 1.2169 - val_accuracy: 0.5438
#
# Epoch 00084: val_loss did not improve from 0.73210
# Epoch 85/100
# 900/900 [==============================] - 217s 241ms/step - loss: 1.3606 - accuracy: 0.4869 - val_loss: 1.2152 - val_accuracy: 0.5596
#
# Epoch 00085: val_loss did not improve from 0.73210
# Epoch 86/100
# 900/900 [==============================] - 226s 251ms/step - loss: 1.3598 - accuracy: 0.4818 - val_loss: 1.2672 - val_accuracy: 0.5553
#
# Epoch 00086: val_loss did not improve from 0.73210
# Epoch 87/100
# 900/900 [==============================] - 223s 248ms/step - loss: 1.3688 - accuracy: 0.4855 - val_loss: 1.3291 - val_accuracy: 0.5633
#
# Epoch 00087: val_loss did not improve from 0.73210
# Epoch 88/100
# 900/900 [==============================] - 219s 243ms/step - loss: 1.3604 - accuracy: 0.4870 - val_loss: 1.0615 - val_accuracy: 0.5577
#
# Epoch 00088: val_loss did not improve from 0.73210
# Epoch 89/100
# 900/900 [==============================] - 217s 241ms/step - loss: 1.3587 - accuracy: 0.4844 - val_loss: 1.1605 - val_accuracy: 0.5599
#
# Epoch 00089: val_loss did not improve from 0.73210
# Epoch 90/100
# 900/900 [==============================] - 220s 244ms/step - loss: 1.3628 - accuracy: 0.4863 - val_loss: 1.1600 - val_accuracy: 0.5492
#
# Epoch 00090: val_loss did not improve from 0.73210
# Epoch 91/100
# 900/900 [==============================] - 218s 242ms/step - loss: 1.3648 - accuracy: 0.4819 - val_loss: 1.3419 - val_accuracy: 0.5535
#
# Epoch 00091: val_loss did not improve from 0.73210
# Epoch 92/100
# 900/900 [==============================] - 215s 239ms/step - loss: 1.3650 - accuracy: 0.4844 - val_loss: 0.9036 - val_accuracy: 0.5590
#
# Epoch 00092: val_loss did not improve from 0.73210
# Epoch 93/100
# 900/900 [==============================] - 218s 243ms/step - loss: 1.3608 - accuracy: 0.4868 - val_loss: 1.1673 - val_accuracy: 0.5513
#
# Epoch 00093: val_loss did not improve from 0.73210
# Epoch 94/100
# 900/900 [==============================] - 217s 242ms/step - loss: 1.3613 - accuracy: 0.4832 - val_loss: 1.1040 - val_accuracy: 0.5503
#
# Epoch 00094: val_loss did not improve from 0.73210
# Epoch 95/100
# 900/900 [==============================] - 219s 244ms/step - loss: 1.3684 - accuracy: 0.4827 - val_loss: 1.2757 - val_accuracy: 0.5611
#
# Epoch 00095: val_loss did not improve from 0.73210
# Epoch 96/100
# 900/900 [==============================] - 220s 245ms/step - loss: 1.3645 - accuracy: 0.4845 - val_loss: 1.1304 - val_accuracy: 0.5628
#
# Epoch 00096: val_loss did not improve from 0.73210
# Epoch 97/100
# 900/900 [==============================] - 205s 227ms/step - loss: 1.3575 - accuracy: 0.4887 - val_loss: 1.1101 - val_accuracy: 0.5614
#
# Epoch 00097: val_loss did not improve from 0.73210
# Epoch 98/100
# 900/900 [==============================] - 163s 181ms/step - loss: 1.3630 - accuracy: 0.4874 - val_loss: 0.9125 - val_accuracy: 0.5502
#
# Epoch 00098: val_loss did not improve from 0.73210
# Epoch 99/100
# 900/900 [==============================] - 163s 182ms/step - loss: 1.3534 - accuracy: 0.4877 - val_loss: 0.4808 - val_accuracy: 0.5432
#
# Epoch 00099: val_loss improved from 0.73210 to 0.48083, saving model to analisis_emociones_faciales.h5.h5
# Epoch 100/100
# 900/900 [==============================] - 149s 166ms/step - loss: 1.3597 - accuracy: 0.4855 - val_loss: 0.5978 - val_accuracy: 0.5493
#
# Epoch 00100: val_loss did not improve from 0.48083

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(1,len(acc)+1,1)

plt.plot ( epochs,     acc, 'r--', label='Training acc'  )
plt.plot ( epochs, val_acc,  'b', label='Validation acc')
plt.title ('Training and validation accuracy')
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()

plt.plot ( epochs,     loss, 'r--' )
plt.plot ( epochs, val_loss ,  'b' )
plt.title ('Training and validation loss'   )
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()
# Out:
# No handles with labels found to put in legend.

# %%
from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

# %%
face_classifier = face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

classifier =load_model("analisis_emociones_faciales.h5")

class_labels = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

cap = cv2.VideoCapture(0)

# %%
cap = cv2.VideoCapture(0)
while True:
    # Grab a single frame of video
    ret, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    faces = face_classifier.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h,x:x+w]
        roi_gray = cv2.resize(roi_gray,(48,48),interpolation=cv2.INTER_AREA)
    # rect,face,image = face_detector(frame)


        if np.sum([roi_gray])!=0:
            roi = roi_gray.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi,axis=0)

        # make a prediction on the ROI, then lookup the class

            preds = classifier.predict(roi)[0]
            label=class_labels[preds.argmax()]
            label_position = (x,y)
            cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        else:
            cv2.putText(frame,'No Face Found',(20,60),cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
